# %% [markdown]
# # Replicating Goyal and Welch (2008, RFS)

# %% [markdown]
# This Notebook replicates the annual analyses in Goyal and Welch (2008, RFS).
#
#
# ***Abstract:***
#
# *Our article comprehensively reexamines the performance of variables that have been suggested by the academic literature to be good predictors of the equity premium. We find that by and large, these models have predicted poorly both in-sample (IS) and out-of-sample (OOS) for 30 years now; these models seem unstable, as diagnosed by their out-of-sample predictions and other statistics; and these models would not have helped an investor with access only to available information to profitably time the market.*

# %%
# Required packages

import pandas as pd
import numpy as np
import warnings

import statsmodels.api as sm
import matplotlib.pyplot as plt

from pandas.tseries.offsets import MonthEnd


warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### 1. $\quad$ Data
#
# The PredictorData.xls file can be downloaded from Amit Goyal's website:
#
# https://docs.google.com/spreadsheets/d/1bM7vCWd3WOt95Sf9qjLPZjoiafgF_8EG/edit?gid=407859737#gid=407859737$

# %% [markdown]
# #### 1.1. $\quad$ Import the data
#
# We then import the data.

# %%
from pathlib import Path

xls_path = Path('PredictorData2023.xlsx')
if not xls_path.exists():
    xls_path = Path('Lecture1') / xls_path


goyal = pd.ExcelFile(xls_path)
df = {sheet_name: goyal.parse(sheet_name) for sheet_name in goyal.sheet_names}

# %% [markdown]
# #### 1.2. $\quad$ Data pre-processing
#
# Equity premium prediction is a time series forecasting task.
#
# Let's start by creating datetime indices for the monthly and annual data.

# %%
# create date index for monthly data
df['Monthly']['yyyymm'] = pd.to_datetime(df['Monthly']['yyyymm'].astype(str), format='%Y%m')
df['Monthly'].set_index('yyyymm', inplace=True)
df['Monthly'].index = df['Monthly'].index.to_period('M').to_timestamp('M')


# create date index for annual data
df['Annual']['yyyy'] = pd.to_datetime(df['Annual']['yyyy'].astype(str), format='%Y')
df['Annual'].set_index('yyyy', inplace=True)
df['Annual'].index = df['Annual'].index.to_period('Y').to_timestamp('Y')

df = df['Annual']

df.head()
# Out:
#             Index   D12   E12  b/m  tbl  AAA  BAA  lty  cay  ntis     Rfree  \
# yyyy
# 1871-12-31   4.74  0.26  0.40  NaN  NaN  NaN  NaN  NaN  NaN   NaN  0.049610
# 1872-12-31   5.07  0.30  0.43  NaN  NaN  NaN  NaN  NaN  NaN   NaN  0.074134
# 1873-12-31   4.42  0.33  0.46  NaN  NaN  NaN  NaN  NaN  NaN   NaN  0.091715
# 1874-12-31   4.54  0.33  0.46  NaN  NaN  NaN  NaN  NaN  NaN   NaN  0.058314
# 1875-12-31   4.37  0.30  0.36  NaN  NaN  NaN  NaN  NaN  NaN   NaN  0.045897
#
#             infl  eqis  ltr  corpr  svar  csp  ik  CRSP_SPvw  CRSP_SPvwx
# yyyy
# 1871-12-31   NaN   NaN  NaN    NaN   NaN  NaN NaN        NaN         NaN
# 1872-12-31   NaN   NaN  NaN    NaN   NaN  NaN NaN        NaN         NaN
# 1873-12-31   NaN   NaN  NaN    NaN   NaN  NaN NaN        NaN         NaN
# 1874-12-31   NaN   NaN  NaN    NaN   NaN  NaN NaN        NaN         NaN
# 1875-12-31   NaN   NaN  NaN    NaN   NaN  NaN NaN        NaN         NaN

# %% [markdown]
# We can then create the predictor variables and target variable, as described in Goyal and Welch.

# %%
# Dividend Price Ratio (d/p) is the difference between the log of dividends and the log of prices.
df['d/p'] = np.log(df['D12']) - np.log(df['Index'])

# Dividend Yield (d/y) is the difference between the log of dividends and the log of lagged prices.
df['d/y'] = np.log(df['D12'])- np.log(df['Index'].shift(1))

# Earnings Price Ratio (e/p) is the difference between the log of earnings and the log of prices.
df['e/p'] = np.log(df['E12']) - np.log(df['Index'])

# Dividend Payout Ratio (d/e) is the difference between the log of dividends and the log of earnings.
df['d/e'] = np.log(df['D12']) - np.log(df['E12'])

# Term Spread (tms) is the difference between the long term yield on government bonds and the T-bill.
df['tms'] = df['lty'] - df['tbl']

# Default Yield Spread (dfy): is the difference between BAA- and AAA- rated corporate bond yields.
df['dfy'] = df['BAA'] - df['AAA']

# Default Return Spread (dfr): is the difference between the return on long-term corporate bonds and returns on the long-term government bonds.
df['dfr'] = df['corpr'] - df['ltr']

# Calculate Index Price plus Dividends
df['IndexDiv'] = df['Index'] + df['D12']

# Calculate logretdiv (log return with dividends)
df['logretdiv'] = np.log(df['IndexDiv'] / df['Index'].shift(1))

# Calculate logRfree
df['logRfree'] = np.log(df['Rfree'] + 1)

# equity premium, i.e., the total rate of return on the stock market minus the prevailing short-term interest rate.
df['premium'] = df['logretdiv'] - df['logRfree']

df = df.drop(columns=['Index', 'csp', 'D12', 'E12', 'AAA', 'BAA', 'CRSP_SPvwx', 'corpr','Rfree', 'CRSP_SPvw'])

df.head()
# Out:
#             b/m  tbl  lty  cay  ntis  infl  eqis  ltr  svar  ik  ...  \
# yyyy                                                             ...
# 1871-12-31  NaN  NaN  NaN  NaN   NaN   NaN   NaN  NaN   NaN NaN  ...
# 1872-12-31  NaN  NaN  NaN  NaN   NaN   NaN   NaN  NaN   NaN NaN  ...
# 1873-12-31  NaN  NaN  NaN  NaN   NaN   NaN   NaN  NaN   NaN NaN  ...
# 1874-12-31  NaN  NaN  NaN  NaN   NaN   NaN   NaN  NaN   NaN NaN  ...
# 1875-12-31  NaN  NaN  NaN  NaN   NaN   NaN   NaN  NaN   NaN NaN  ...
#
#                  d/y       e/p       d/e  tms  dfy  dfr  IndexDiv  logretdiv  \
# yyyy
# 1871-12-31       NaN -2.472328 -0.430783  NaN  NaN  NaN      5.00        NaN
# 1872-12-31 -2.760010 -2.467311 -0.360003  NaN  NaN  NaN      5.37   0.124791
# 1873-12-31 -2.732003 -2.262668 -0.332134  NaN  NaN  NaN      4.75  -0.065196
# 1874-12-31 -2.594802 -2.289456 -0.332134  NaN  NaN  NaN      4.87   0.096954
# 1875-12-31 -2.716900 -2.496414 -0.182322  NaN  NaN  NaN      4.67   0.028232
#
#             logRfree   premium
# yyyy
# 1871-12-31  0.048419       NaN
# 1872-12-31  0.071515  0.053276
# 1873-12-31  0.087750 -0.152946
# 1874-12-31  0.056677  0.040277
# 1875-12-31  0.044875 -0.016643
#
# [5 rows x 21 columns]

# %%
fig, (ax1, ax2) = plt.subplots(
    1, 2,
    figsize=(12, 4),
    sharex=True
)

for ax, col, title in [
    (ax1, 'premium',          'Equity Premium'),
    (ax2, 'dfy',              'Default Yield Spread')
]:
    # thicker, simpler line
    ax.plot(df.index, df[col],
            color='blue', linewidth=2, label=title)

    # titles & labels
    ax.set_title(title, fontsize=14)
    ax.set_xlabel('Year',   fontsize=12)
    ax.set_ylabel(title,     fontsize=12)

    # light dotted grid
    ax.grid(True, linestyle=':')

    # legend with no frame
    ax.legend(loc='upper left', frameon=False, fontsize=10)

    # remove top & right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# rotate & align date labels
fig.autofmt_xdate()

fig.tight_layout()
plt.show()


# Display the plot
plt.show()

# %% [markdown]
# ### 2. $\quad$ Defining the model
#
# Let's replicate the analysis performed in Goyal and Welch (2008, RFS).

# %%
def get_statistics(ts_df, indep, dep, h=1, start='1872-12-31', end='2004-12-31', est_periods_OOS=20):
    ts_df = ts_df.copy()
    ts_df['lag_indep'] = ts_df[indep].shift(h)

    date_index = pd.to_datetime(ts_df.index)
    start_date = pd.to_datetime(start)
    end_date = pd.to_datetime(end)

    reg_data = (
        ts_df.loc[start:end, [dep, 'lag_indep']]
        .replace([np.inf, -np.inf], np.nan)
        .dropna()
    )

    if len(reg_data) < 3:
        raise ValueError('Not enough finite observations to estimate the in-sample regression.')

    #### IS ANALYSIS

    # 1. Historical mean model, evaluated on the same sample as the OLS model.
    avg = reg_data[dep].mean()
    IS_error_N = reg_data[dep] - avg

    # 2. OLS model
    reg = sm.OLS(reg_data[dep], sm.add_constant(reg_data['lag_indep'])).fit()
    IS_error_A = reg.resid

    #### OOS ANALYSIS
    OOS_error_N = []
    OOS_error_A = []
    forecast_dates = []

    current_dates = date_index[
        (date_index >= start_date + pd.DateOffset(years=est_periods_OOS))
      & (date_index < end_date)
    ]

    for current_date in current_dates:
        next_date = current_date + pd.DateOffset(years=h) + MonthEnd(0)
        if next_date not in ts_df.index:
            continue

        actual_ERP = ts_df.loc[next_date, dep]
        current_indep = ts_df.loc[current_date, indep]
        if not np.isfinite(actual_ERP) or not np.isfinite(current_indep):
            continue

        # 1. Historical mean model
        historical_data = (
            ts_df.loc[start:current_date, dep]
            .replace([np.inf, -np.inf], np.nan)
            .dropna()
        )

        # 2. OLS model
        training_data = (
            ts_df.loc[start:current_date, [dep, 'lag_indep']]
            .replace([np.inf, -np.inf], np.nan)
            .dropna()
        )

        if len(historical_data) == 0 or len(training_data) < 3:
            continue

        reg_OOS = sm.OLS(training_data[dep], sm.add_constant(training_data['lag_indep'])).fit()
        indep_values = pd.DataFrame({'lag_indep': [current_indep]}, index=[next_date])
        indep_values = sm.add_constant(indep_values, has_constant='add')

        pred_ERP = reg_OOS.predict(indep_values).iloc[0]
        OOS_error_N.append(actual_ERP - historical_data.mean())
        OOS_error_A.append(actual_ERP - pred_ERP)
        forecast_dates.append(next_date)

    if len(OOS_error_N) == 0:
        raise ValueError('No valid out-of-sample forecasts were produced.')

    OOS_error_N = np.array(OOS_error_N, dtype=float)
    OOS_error_A = np.array(OOS_error_A, dtype=float)

    # Compute statistics
    MSE_N = np.mean(OOS_error_N**2)
    MSE_A = np.mean(OOS_error_A**2)
    T = len(reg_data)
    OOS_R2 = 1 - MSE_A / MSE_N
    OOS_oR2 = OOS_R2 - (1 - OOS_R2) * (reg.df_resid / (T - 1))
    dRMSE = np.sqrt(MSE_N) - np.sqrt(MSE_A)

    #### CREATE PLOT
    IS = (IS_error_N**2).cumsum() - (IS_error_A**2).cumsum()
    OOS = np.cumsum(OOS_error_N**2) - np.cumsum(OOS_error_A**2)

    is_plot = IS.reindex(forecast_dates)
    oos_plot = pd.Series(OOS, index=forecast_dates)
    df_plot = pd.DataFrame({
        'x': is_plot.index,
        'IS': is_plot.values,
        'OOS': oos_plot.reindex(is_plot.index).values
    }).dropna()

    if df_plot.empty:
        raise ValueError('No overlapping dates are available for the IS and OOS plot.')

    # Re-base the IS curve at zero.
    df_plot['IS'] -= df_plot['IS'].iloc[0]

    band = 0.015
    df_plot['lower'] = df_plot['OOS'] - band
    df_plot['upper'] = df_plot['OOS'] + band

    fig, ax = plt.subplots(figsize=(7, 4))

    ymin, ymax = -0.2, 0.2
    ax.axhspan(ymax, ymax + 0.02, color='lavender', alpha=0.7, zorder=0)
    ax.axhspan(ymin - 0.02, ymin, color='lavender', alpha=0.7, zorder=0)

    x_values = pd.to_datetime(df_plot['x']).to_numpy()
    ax.plot(x_values, df_plot['OOS'], color='black', linewidth=2, label='OOS')
    ax.fill_between(
        x_values,
        df_plot['lower'].to_numpy(),
        df_plot['upper'].to_numpy(),
        color='violet',
        alpha=0.3
    )
    ax.plot(x_values, df_plot['IS'], linestyle='--', color='black', linewidth=1.5, label='IS')

    ax.axvspan(pd.Timestamp('1973-01-01'), pd.Timestamp('1975-12-31'), color='red', alpha=0.6)
    ax.text(pd.Timestamp('1974-07-01'), ymax - 0.02, 'Oil Shock\n1974',
            ha='center', va='top', rotation=90, weight='bold')

    ax.text(0.5, 0.90, str(indep), transform=ax.transAxes,
            ha='center', va='center', fontsize=36, alpha=0.25)

    ax2 = ax.twinx()
    ax2.set_ylim(ymin, ymax)

    ax.set_xlim(x_values.min(), x_values.max())
    ax.set_ylim(ymin, ymax)
    ax.set_xlabel('Year')
    ax.set_ylabel('Cumulative SSE Difference')
    ax.grid(True, linestyle=':')
    ax.legend(loc='lower right', frameon=False)

    plt.show()

    return {
        'IS_R2': reg.rsquared,
        'IS_aR2': reg.rsquared_adj,
        'OOS_R2': OOS_R2,
        'OOS_oR2': OOS_oR2,
        'dRMSE': dRMSE
    }

# %% [markdown]
# ### 3. $\quad$ Execution

# %%
# Selecting the Dividend Price Ratio (d/p) as the independent variable, and the equity premium as the dependent variable.
df = df[["d/p", "premium"]]

# running the model
get_statistics(df, "d/p", "premium")
# Out:
# {'IS_R2': 0.011941674588687334,
#  'IS_aR2': 0.004399244623715548,
#  'OOS_R2': -0.012347866456110523,
#  'OOS_oR2': -1.017026430893614,
#  'dRMSE': -0.0011517723288715087}
